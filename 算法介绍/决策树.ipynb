# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets


# 读取示例数据
iris = datasets.load_iris()
X_data=iris.data
Y_data=iris.target

# 训练集和测试集分割
cut_point_index=int(0.7*len(iris.data))
train_x=X_data[:cut_point_index]
train_y=Y_data[:cut_point_index]
test_x=X_data[cut_point_index:]
test_y=Y_data[cut_point_index:]

# 训练模型
model = DecisionTreeClassifier()
model.fit(train_x, train_y)

# 预测并评估
predict_y=model.predict(test_x)
right_classif=0
for i in range(len(test_y)):
    if predict_y[i]==test_y[i]:
        right_classif=right_classif+1

print("分类的总数为 {}，分类正确的点数为 : {}，分类正确比:{}".format(len(test_y),right_classif,right_classif/len(test_y)))
# Out:
# 分类的总数为 45，分类正确的点数为 : 35，分类正确比:0.7777777777777778

# %%
tree.plot_tree(clf)
# Out:
# [Text(167.4, 199.32, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(141.64615384615385, 163.07999999999998, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(193.15384615384616, 163.07999999999998, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(103.01538461538462, 126.83999999999999, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(51.50769230769231, 90.6, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(25.753846153846155, 54.359999999999985, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(77.26153846153846, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(154.52307692307693, 90.6, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(128.76923076923077, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(180.27692307692308, 54.359999999999985, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(154.52307692307693, 18.119999999999976, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(206.03076923076924, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(283.2923076923077, 126.83999999999999, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(257.53846153846155, 90.6, 'X[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(231.7846153846154, 54.359999999999985, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(283.2923076923077, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(309.04615384615386, 90.6, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# 设置图片尺寸
figure(figsize=(8, 6), dpi=80)

# 可视化决策树
tree.plot_tree(model)
# Out:
# [Text(165.33333333333334, 317.09999999999997, 'X[2] <= 2.45\ngini = 0.544\nsamples = 105\nvalue = [50, 50, 5]'),
#  Text(82.66666666666667, 226.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(248.0, 226.5, 'X[3] <= 1.75\ngini = 0.165\nsamples = 55\nvalue = [0, 50, 5]'),
#  Text(165.33333333333334, 135.89999999999998, 'gini = 0.0\nsamples = 49\nvalue = [0, 49, 0]'),
#  Text(330.6666666666667, 135.89999999999998, 'X[2] <= 4.95\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5]'),
#  Text(248.0, 45.30000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(413.33333333333337, 45.30000000000001, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]')]
